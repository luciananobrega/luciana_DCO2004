# %% [markdown]
# # Entregáveis hands-on 5

# %% [markdown]
# ## Prática 1: Modulação AM-DSB

# %% [markdown]
# ### Parte 1 - expressando três casos clássicos de modulação

# %% [markdown]
# #### i) Modulação a 100%
#
# Para que haja correto funcionamento de um transmissor de AM de modo que seja obtido maior alcance e para que ele não cause interferências a modulação deve ser feita de forma bem determinada.
#
# Na prática a modulação é medida na forma de uma porcentagem. Assim, uma modulação de 100% é aquela em que a amplitude do sinal varia entre zero e o valor máximo.
#
# No codigo, alterou-se o indice de modulacao (Mu) para 1.

# %%
# Importa bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack

# Parâmetros do sinal
Ac = 2                                                         # Amplitude da portadora
Mu = 1.0                                                       # Índice de modulação
fc = 25000                                                     # Frequência da portadora Hz
fm = 2000
N = 1000
Ts = 1e-6                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
s = Ac*(1+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

# Cálculo da FFT de AM-DSB
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(s)))/N                           # Cálculo da FFT
Ns = len(s)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new = np.zeros(Nk)                                         # Inicialização do vetor da frequência
fsampling = 1/Ts                                               # Taxa de amostragem
freq = (fsampling/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new[i] = S_f[kk]
    else :
        S_f_new[i] = S_f[Ns+kk]

# Gráfico do AM-DSB no tempo
plt.figure(1,[10,7])
plt.subplot(211)
plt.plot(t,s)
plt.title("Sinal AM no tempo - AM-DSB (padrão)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

# Gráfico do AM-DSB na frequência
plt.subplot(212)
plt.title("AM-DSB na frequência")
plt.xlabel("Frequência [kHz]")
plt.ylabel("Magnitude")
plt.stem(freq/1e3,S_f_new)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ii) Submodulação
#
# Uma modulação pobre, em que a amplitude da portadora varie pouco de intensidade faz com que o rendimento da estação seja pequeno.
#
# Uma modulação pobre, menor que 100% não faz com que o sinal varie em toda sua amplitude.

# %%
# Importa bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack

# Parâmetros do sinal
Ac = 2                                                         # Amplitude da portadora
Mu = 0                                                       # Índice de modulação
fc = 25000                                                     # Frequência da portadora Hz
fm = 2000
N = 1000
Ts = 1e-6                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
s = Ac*(1+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

# Cálculo da FFT de AM-DSB
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(s)))/N                           # Cálculo da FFT
Ns = len(s)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new = np.zeros(Nk)                                         # Inicialização do vetor da frequência
fsampling = 1/Ts                                               # Taxa de amostragem
freq = (fsampling/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new[i] = S_f[kk]
    else :
        S_f_new[i] = S_f[Ns+kk]

# Gráfico do AM-DSB no tempo
plt.figure(1,[10,7])
plt.subplot(211)
plt.plot(t,s)
plt.title("Sinal AM no tempo - AM-DSB (padrão)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

# Gráfico do AM-DSB na frequência
plt.subplot(212)
plt.title("AM-DSB na frequência")
plt.xlabel("Frequência [kHz]")
plt.ylabel("Magnitude")
plt.stem(freq/1e3,S_f_new)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### iii) Sobremodulação
# Pode ocorrer ainda que a modulação supere os 100%, caso em que teremos instantes em que o sinal se anula.
#
# Por outro lado, uma modulação excessiva que ultrapasse a variação da amplitude do sinal de alta frequência faz com que ocorram distorções e, mais do que isso, sejam geradas interferências.
#
# Um sinal não deve ser modulado em mais do que 100%, pois além de ocorrerem distorções dos sinais, são geradas bandas laterais fora das faixas designadas causando interferências. Neste caso, dizemos que ocorre uma sobremodulação.

# %%
# Importa bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack

# Parâmetros do sinal
Ac = 2                                                         # Amplitude da portadora
Mu = 1.5                                                       # Índice de modulação
fc = 25000                                                     # Frequência da portadora Hz
fm = 2000
N = 1000
Ts = 1e-6                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
s = Ac*(1+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

# Cálculo da FFT de AM-DSB
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(s)))/N                           # Cálculo da FFT
Ns = len(s)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new = np.zeros(Nk)                                         # Inicialização do vetor da frequência
fsampling = 1/Ts                                               # Taxa de amostragem
freq = (fsampling/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new[i] = S_f[kk]
    else :
        S_f_new[i] = S_f[Ns+kk]

# Gráfico do AM-DSB no tempo
plt.figure(1,[10,7])
plt.subplot(211)
plt.plot(t,s)
plt.title("Sinal AM no tempo - AM-DSB (padrão)")
plt.xlabel("Tempo [s]")
plt.ylabel("Amplitude")

# Gráfico do AM-DSB na frequência
plt.subplot(212)
plt.title("AM-DSB na frequência")
plt.xlabel("Frequência [kHz]")
plt.ylabel("Magnitude")
plt.stem(freq/1e3,S_f_new)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Parte 2 - Cálculo da potência com as amostras do sinal AM-DSB

# %%
import numpy as np
import time
import scipy.signal as sci
from scipy import fftpack
## Parâmetros do sinal

Ac = 2                                                         # Amplitude da portadora
Mu = 1                                                        # Índice de modulação
fc = 25000                                                     # Frequência da portadora Hz
fm = 2000
N = 1000
Ts = 1e-6                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
s = Ac*(1+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t)

Pvar = np.var(s)                                               # Calculo da potencia via variancia
print('Potência calculada variancia = ',Pvar)

# Cálculo da FFT de AM-DSB
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(s)))/N                           # Cálculo da FFT
Ns = len(s)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new = np.zeros(Nk)                                         # Inicialização do vetor da frequência
Fs = 1/Ts                                               # Taxa de amostragem
freq = (Fs/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new[i] = S_f[kk]
    else :
        S_f_new[i] = S_f[Ns+kk]
  
Nfft = 1000
Xfft=np.fft.fft(s,Nfft)              # Encontra a FFT
Xfft = np.array_split(Xfft,2)[0]
f=np.arange(0,0.5*Fs,Fs/Nfft)        # Eixo da frequência


P_portadora = (Ac**2)/2

P_bandas_laterais= (Ac**2)*(Mu**2)/4

P_total = P_bandas_laterais + P_portadora

print('A potência estimada é',P_total)
# Out:
# Potência calculada variancia =  3.0
# A potência estimada é 3.0

# %% [markdown]
# ## Prática 2: recepção AM-DSB (detecção de envoltória)

# %% [markdown]
# ### Para $\tau=10^{-4}$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 1e-4                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

print('Erro médio quadrático: ', sum((x_env-x_envIdeal)**2)/len(x_env))
# Out:
# Erro médio quadrático:  0.126750715881

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 1e-4                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

# gráfico composto
plt.figure(1,[10,7])
plt.title("Detecção de envoltória")
plt.ylabel("Amplitude")
plt.xlabel("Tempo(ms)")
envoltoria_ideal = plt.plot(t*1000,x_envIdeal)
sinal_transmitido = plt.plot(t*1000,x_AM)
detector_de_saida = plt.plot(t*1000,x_env)
plt.grid()
plt.legend(["Envoltória ideal","Onda AM retificada","Envoltória recuperada"])
plt.show()

plt.show()

# %% [markdown]
# ### Para $\tau = 2\cdot10^{-4}$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 2*1e-4                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

print('Erro médio quadrático: ', sum((x_env-x_envIdeal)**2)/len(x_env))
# Out:
# 0.0536946487174

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 2*1e-4                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

# gráfico composto
plt.figure(1,[10,7])
plt.title("Detecção de envoltória")
plt.ylabel("Amplitude")
plt.xlabel("Tempo(ms)")
envoltoria_ideal = plt.plot(t*1000,x_envIdeal)
sinal_transmitido = plt.plot(t*1000,x_AM)
detector_de_saida = plt.plot(t*1000,x_env)
plt.grid()
plt.legend(["Envoltória ideal","Onda AM retificada","Envoltória recuperada"])
plt.show()

plt.show()

# %% [markdown]
# ### Para $\tau = 4\cdot10^{-3}$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 4*1e-3                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

print('Erro médio quadrático:', sum((x_env-x_envIdeal)**2)/len(x_env))
# Out:
# Erro médio quadrático: 0.410199065112

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import fftpack

tau = 4*1e-3                                                      # Constante de tempo do detector de envelope
Ts=1e-6                                                         # Definição do período
t = np.arange(1000)*Ts                                          # Definição do vetor tempo
fc = 10000                                                      # Frequência da portadora.
fm = 1500                                                       # Frequência do sinal
Mu = 0.6                                                        # Índice de modulaçao.
Ac = 1.0
x_AMo = Ac*(1.0+Mu*np.cos(2*np.pi*fm*t))*np.cos(2*np.pi*fc*t);  # Onda Modulada AM-DSB

x_envIdeal = np.abs(Ac*(1.0+Mu*np.cos(2*np.pi*fm*t)))           # Envoltória ideal

# Detector de envoltória
x_AM = x_AMo*(x_AMo>0)                                          # Efeito do diodo (semiciclo positivo)
x_env = np.zeros(len(x_AM))
Ns = len(x_AM)
out = -1
for i in range(Ns):
    inp = x_AM[i]
    if inp>=out:
        out = inp            # Caso 1: x_am(t) > Vc(t) (carga do capacitor)
    else:
        out *= (1-Ts/tau)    # Caso 2: x_am(t) < Vc(t) (descarga do capacitor)
    x_env[i] = out

# gráfico composto
plt.figure(1,[10,7])
plt.title("Detecção de envoltória")
plt.ylabel("Amplitude")
plt.xlabel("Tempo(ms)")
envoltoria_ideal = plt.plot(t*1000,x_envIdeal)
sinal_transmitido = plt.plot(t*1000,x_AM)
detector_de_saida = plt.plot(t*1000,x_env)
plt.grid()
plt.legend(["Envoltória ideal","Onda AM retificada","Envoltória recuperada"])
plt.show()

plt.show()

# %% [markdown]
# Como visto nas simulações e nos gráficos plotados, dependendo da constante de descarga do capacitor, a detecção (e o erro quadrático médio) será maior ou menor). Caso $\tau$ seja muito menor que o período da portadora, o capacitor se descarregará muito rápido quando a portadora cai abaixo do seu valor de pico, o que fará com que a saída do detector não siga a envoltória desta onda.
#
# Se, por outro lado, o valor for muito maior que a máxima do sinal modulador, então o capacitor se descarregará muito lentamente e a saída do detector não seguirá a envoltória da onda AM, resultando em um corte diagonal do sinal.

# %% [markdown]
# ## Prática 8: Sinal analítico, Transformada de Hilbert e seu uso em demodulação

# %%
# Sinal modulante:
 # Frequência de amostragem = 600;
 # Eixo do tempo de 0 a 1;
 # Frequência do sinal = 3;
# Sinal portadora:
 # Frequência da portadora = 50;
 # Indice de modulação = 0,7

# %matplotlib inline

# Importa bibliotecas
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
from scipy.signal import hilbert

# Parâmetros do sinal
Ac = 1                                                         # Amplitude da portadora
Mu = 0.7                                                       # Índice de modulação
fc = 50                                                        # Frequência da portadora Hz
fm = 3
N = 1000
Ts = 1/600                                                      # Tempo de amostragem pequeno (modelar sinal contínuo)
t = np.arange(N)*Ts
m_t = np.cos(2*np.pi*fm*t)
s = Ac*(1+Mu*m_t)*np.cos(2*np.pi*fc*t)        # Sinal modulado


# Demodulação AM-DSB
 # Regeneração do sinal modulante por meio da transformada de Hilbert
 # Regeneração da portadora por meio da transformada de Hilbert

# Hilbert
z_t = hilbert(s)                                             # Sinal analítico (real + imaginário)
m_est = abs(z_t)

ang = np.angle(z_t)
portadora = np.cos(ang)

# Gráficos
 # Gráfico do sinal modulante, do sinal modulado e do sinal regenerado no tempo
    # (três linhas no mesmo gráfico, identificadas por legenda)
plt.title('Modulação e demodulação AM pela ')
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.plot(t,m_t,t,s,t,m_est)
plt.ylim([-2,2])
plt.xlim([0,1])
plt.legend(['sinal modulante','sinal modulado', 'sinal regenerado', 'angle'])
plt.show()

plt.title('Modulação e demodulação AM pela ')
plt.xlabel('Tempo [s]')
plt.ylabel('Amplitude')
plt.plot(t,s,t, portadora)
plt.ylim([-2,2])
plt.xlim([0,1])
plt.legend(['sinal modulante','portadora'])
plt.show()

# Espectro do sinal modulante e regenerado (duas linhas no mesmo gráfico, identificadas por legenda)

# Cálculo da FFT modulante
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f = 2.0*np.abs((fftpack.fft(m_t)))/N                           # Cálculo da FFT
Ns = len(m_t)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new = np.zeros(Nk)                                         # Inicialização do vetor da frequência
fsampling = 1/Ts                                               # Taxa de amostragem
freq = (fsampling/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new[i] = S_f[kk]
    else:
        S_f_new[i] = S_f[Ns+kk]


# Cálculo da FFT sinal regenerado
lfft = 30                                                      # Número pontos da fft
k = np.arange(-lfft,lfft)                                      # Vetor de frequências 
S_f_mod = 2.0*np.abs((fftpack.fft(m_est)))/N                           # Cálculo da FFT
Ns = len(m_est)                                                    # Comprimento do sinal modulado
Nk = len(k)                                                    # Comprimento do sinal em frequência

# A fft em 30 pontos (para melhor visualização)
S_f_new_mod = np.zeros(Nk)                                     # Inicialização do vetor da frequência
fsampling = 1/Ts                                               # Taxa de amostragem
freq = (fsampling/Ns)*k                                        # Eixo de frequências
for i in range(Nk):
    kk = k[i]
    if kk>=0:
        S_f_new_mod[i] = S_f_mod[kk]
    else:
        S_f_new_mod[i] = S_f_mod[Ns+kk]

        
# Gráfico do AM-DSB na frequência
plt.title("AM-DSB na frequência")
plt.xlabel("Frequência [kHz]")
plt.ylabel("Magnitude")
plt.stem(freq/1e3, S_f_new, freq/1e3, S_f_new_mod)
plt.tight_layout()
plt.show()

# Gráfico do AM-DSB no tempo
#plt.figure(1,[10,7])
#plt.subplot(211)
#plt.plot(t,s)
#plt.title("Sinal AM no tempo - AM-DSB (padrão)")
#plt.xlabel("Tempo [s]")
#plt.ylabel("Amplitude")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/labsim/anaconda3/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_axes.py in stem(self, *args, **kwargs)
#    2395         try:
# -> 2396             linefmt = kwargs['linefmt']
#    2397         except KeyError:
#
# KeyError: 'linefmt'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-18c2889d6e54> in <module>()
#     103 plt.xlabel("Frequência [kHz]")
#     104 plt.ylabel("Magnitude")
# --> 105 plt.stem(freq/1e3, S_f_new, freq/1e3, S_f_new_mod)
#     106 plt.tight_layout()
#     107 plt.show()
#
# /home/labsim/anaconda3/envs/py34/lib/python3.4/site-packages/matplotlib/pyplot.py in stem(*args, **kwargs)
#    3544                       mplDeprecation)
#    3545     try:
# -> 3546         ret = ax.stem(*args, **kwargs)
#    3547     finally:
#    3548         ax._hold = washold
#
# /home/labsim/anaconda3/envs/py34/lib/python3.4/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/labsim/anaconda3/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_axes.py in stem(self, *args, **kwargs)
#    2404             else:
#    2405                 linestyle, linemarker, linecolor = \
# -> 2406                     _process_plot_format(linefmt)
#    2407         else:
#    2408             linestyle, linemarker, linecolor = _process_plot_format(linefmt)
#
# /home/labsim/anaconda3/envs/py34/lib/python3.4/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#      92     # handle the multi char special cases and strip them from the
#      93     # string
# ---> 94     if fmt.find('--') >= 0:
#      95         linestyle = '--'
#      96         fmt = fmt.replace('--', '')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'find'
